# %% [markdown]
# This notebook will help you go through the whole project.
#
#                                                                              Zi He

# %%
def main():
    
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt, matplotlib.image as mpimg
    from sklearn.model_selection import train_test_split
    from sklearn import svm
    from sklearn.linear_model import LogisticRegression
    import math
    # %matplotlib inline
    
    import SVM_ZiHe
    import LG_ZiHe
    
    # break the data into training set and test set
    [train_images, test_images,train_labels, test_labels]=SVM_ZiHe.datasplit()
    
    # plot one example of the digits
    SVM_ZiHe.view_one_image(data1=train_images,data2=train_labels)
    
    # feature scaling
    [test_images, train_images]=SVM_ZiHe.feature_scaling(data1=test_images,data2=train_images)
    
    # plot distribution of pixel values
    SVM_ZiHe.histogram(data1=train_images)
    
    # plot the relation of SVM accuracy wrt c and gamma
    print('plot the relation of SVM accuracy wrt c and gamma')
    SVM_ZiHe.correlationSVM_C_gamma(data1=train_images,data2=train_labels,data3=test_images,data4=test_labels)
    
    # plot the relation of LG accuracy wrt c
    print('plot the relation of LG accuracy wrt c')
    LG_ZiHe.correlationLG_C(data1=train_images,data2=train_labels,data3=test_images,data4=test_labels)
    
    
    # plot Gaussian pdf for small sigma value
    SVM_ZiHe.plot_Gaussian_small_sigma()
    
    # plot Gaussian pdf for large sigma value
    SVM_ZiHe.plot_Gaussian_large_sigma()
    
if __name__=="__main__":
    main()
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# /Users/hezi/225 project/SVM_ZiHe.py:36: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   img=data1.iloc[i].as_matrix()
# plot the relation of SVM accuracy wrt c and gamma
# plot the relation of LG accuracy wrt c
